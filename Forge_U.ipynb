# %% [markdown]
# <a href="https://colab.research.google.com/github/EdithForsaken/edith-colab/blob/main/Forge_U.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import subprocess
import os
import time
import json
import shutil
import random
import string
from pathlib import Path
from tqdm import tqdm
from pydantic import BaseModel
from google.colab import drive
import os
from IPython.utils import capture


import os
import shutil

def rename_folder(old_folder, new_folder):
    if os.path.exists(old_folder):
        os.rename(old_folder, new_folder)
        print(f"Folder berhasil diganti menjadi: {new_folder}")
    else:
        print("Folder lama tidak ditemukan!")

def delete_file(file_path):
    if os.path.exists(file_path):
        os.remove(file_path)
        print(f"File {file_path} berhasil dihapus")
    else:
        print("File tidak ditemukan!")

def move_file(source_file, destination_folder):
    os.makedirs(destination_folder, exist_ok=True)
    destination_path = os.path.join(destination_folder, os.path.basename(source_file))
    if os.path.exists(source_file):
        shutil.move(source_file, destination_path)
        print(f"File berhasil dipindahkan ke: {destination_path}")
    else:
        print("File sumber tidak ditemukan!")


import zipfile
import os
from IPython.utils.io import capture_output
from IPython.display import HTML, display, clear_output


def mostrar_en_div_estilizado(contenido):
    from IPython.display import HTML, display
    animation_style = """@keyframes moveBackground{0%{background-position:0 50%}100%{background-position:100% 50%}}"""
    div_style = """background:radial-gradient(circle at 20% 50%,rgba(255,0,0,.4),transparent),radial-gradient(circle at 50% 50%,rgba(0,255,0,.5),transparent),radial-gradient(circle at 80% 50%,rgba(0,0,255,.4),transparent),radial-gradient(circle at 20% 50%,rgba(255,0,0,.4),transparent);background-color:transparent;background-size:400% 400%;animation:moveBackground 60s linear infinite;color:#FFEFDF;padding:15px;border-radius:5px;font-weight:bold;font-family:monospace;box-shadow:0 4px 6px rgba(0,0,0,.5)"""
    display(HTML(f"<style>{animation_style}</style>"))
    div = f'<div class="alert alert-primary" style="{div_style}">{contenido}</div>'
    display(HTML(div))
mostrar_en_div_estilizado(f"<h1>😐 Masih Tahap awal dulu cuy</h1><hr>🌎Proses: 39% - install repo dulu cuy")
with capture_output() as c:
    # !git clone https://github.com/EdithForsaken/edith-colab.git /content/edith-colab
    # %run /content/edith-colab/Satu-Klik/run/Set_Forge_U.ipynb
    delete_file("/content/Forge/asd/controlnet.css")
    move_file("/content/edith-colab/A1/controlnet.css", "/content/Forge/asd")
clear_output()
mostrar_en_div_estilizado(f"<h1>🥱 Buru buru amat, Sabar aja Kak </h1><hr>🌏Proses: 48% - siapin extension tambahan")
with capture_output() as c:
    # %cd -q $Extensions
    # !git clone https://github.com/bluelovers/sd-webui-pnginfo-beautify.git
    # !git clone https://github.com/altoiddealer/sd-webui-segment-anything-altoids
    # !git clone https://github.com/gutris1/sd_civitai_extension
clear_output()
mostrar_en_div_estilizado(f"<h1>🤨 Lu pake AI utk Generate gambar SUS? </h1><hr>🌏Proses: 80% - Install model dulu ya kan..")
with capture_output() as c:
    # %cd -q $CKPT
    # %download https://huggingface.co/cagliostrolab/animagine-xl-4.0/resolve/main/animagine-xl-4.0-opt.safetensors?download=true
clear_output()
mostrar_en_div_estilizado(f"<h1>😇 Jangan Untuk Kejahatan Yaa.. </h1><hr>🌏Proses: 85% - Install Lora dulu ya...")
with capture_output() as c:
    # %cd -q $LORA
    # %download https://civitai.com/models/122359/detail-tweaker-xl
    # %download https://civitai.com/models/669571/pony-add-more-details details-add-more-pony.safetensors
clear_output()
mostrar_en_div_estilizado(f"<h1>🥶 Mempersiapkan Link!!!!</h1><hr>🌍Proses: Mulai menjalankan Stable Diffusion Forge")
# %run /content/edith-colab/profil.ipynb
# %cd -q $WebUI
# %run segsmaker.py --disable-xformers --opt-sdp-attention --cuda-stream --skip-python-version-check
# Out:
# <style>@keyframes moveBackground{0%{background-position:0 50%}100%{background-position:100% 50%}}</style>
# <div class="alert alert-primary" style="background:radial-gradient(circle at 20% 50%,rgba(255,0,0,.4),transparent),radial-gradient(circle at 50% 50%,rgba(0,255,0,.5),transparent),radial-gradient(circle at 80% 50%,rgba(0,0,255,.4),transparent),radial-gradient(circle at 20% 50%,rgba(255,0,0,.4),transparent);background-color:transparent;background-size:400% 400%;animation:moveBackground 60s linear infinite;color:#FFEFDF;padding:15px;border-radius:5px;font-weight:bold;font-family:monospace;box-shadow:0 4px 6px rgba(0,0,0,.5)"><h1>🥶 Mempersiapkan Link!!!!</h1><hr>🌍Proses: Mulai menjalankan Stable Diffusion Forge</div>
# [Errno 2] No such file or directory: '/content/edith-cola'
# /content/Forge/models/Lora
#         <div style="
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             border: 2px solid #ccc;
# ...
